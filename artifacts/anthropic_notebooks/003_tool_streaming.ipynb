# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic


load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
# Helper functions


def add_user_message(messages, message):
    if isinstance(message, list):
        user_message = {
            "role": "user",
            "content": message,
        }
    else:
        user_message = {
            "role": "user",
            "content": [{"type": "text", "text": message}],
        }
    messages.append(user_message)


def add_assistant_message(messages, message):
    if isinstance(message, list):
        assistant_message = {
            "role": "assistant",
            "content": message,
        }
    elif hasattr(message, "content"):
        content_list = []
        for block in message.content:
            if block.type == "text":
                content_list.append({"type": "text", "text": block.text})
            elif block.type == "tool_use":
                content_list.append(
                    {
                        "type": "tool_use",
                        "id": block.id,
                        "name": block.name,
                        "input": block.input,
                    }
                )
        assistant_message = {
            "role": "assistant",
            "content": content_list,
        }
    else:
        # String messages need to be wrapped in a list with text block
        assistant_message = {
            "role": "assistant",
            "content": [{"type": "text", "text": message}],
        }
    messages.append(assistant_message)


def chat_stream(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    tool_choice=None,
    betas=[],
):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tool_choice:
        params["tool_choice"] = tool_choice

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    if betas:
        params["betas"] = betas

    return client.beta.messages.stream(**params)


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Tool definition
from anthropic.types import ToolParam

save_article_schema = ToolParam(
    {
        "name": "save_article",
        "description": "Saves a scholarly journal article",
        "input_schema": {
            "type": "object",
            "properties": {
                "abstract": {
                    "type": "string",
                    "description": "Abstract of the article. One short sentence max",
                },
                "meta": {
                    "type": "object",
                    "properties": {
                        "word_count": {
                            "type": "integer",
                            "description": "Word count",
                        },
                        "review": {
                            "type": "string",
                            "description": "Eight sentence review of the paper",
                        },
                    },
                    "required": ["word_count", "review"],
                },
            },
            "required": ["abstract", "meta"],
        },
    }
)
save_short_article_schema = ToolParam(
    {
        "name": "save_article",
        "description": "Saves a scholarly journal article",
        "input_schema": {
            "type": "object",
            "properties": {
                "abstract": {
                    "type": "string",
                    "description": "Abstract of the article. One short sentence max",
                },
                "meta": {
                    "type": "object",
                    "properties": {
                        "word_count": {
                            "type": "integer",
                            "description": "Word count",
                        },
                        "review": {
                            "type": "string",
                            "description": "Review of paper. One short sentence max",
                        },
                    },
                    "required": ["word_count", "review"],
                },
            },
            "required": ["abstract", "meta"],
        },
    }
)


def save_article(**kwargs):
    return "Article saved!"

# %%
# Tool Running
import json


def run_tool(tool_name, tool_input):
    if tool_name == "save_article":
        return save_article(**tool_input)


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Run conversation
def run_conversation(messages, tools=[], tool_choice=None, fine_grained=False):
    while True:
        with chat_stream(
            messages,
            tools=tools,
            betas=["fine-grained-tool-streaming-2025-05-14"] if fine_grained else [],
            tool_choice=tool_choice,
        ) as stream:
            for chunk in stream:
                if chunk.type == "text":
                    print(chunk.text, end="")

                if chunk.type == "content_block_start":
                    if chunk.content_block.type == "tool_use":
                        print(f'\n>>> Tool Call: "{chunk.content_block.name}"')

                if chunk.type == "input_json" and chunk.partial_json:
                    print(chunk.partial_json, end="")

                if chunk.type == "content_block_stop":
                    print("\n")

            response = stream.get_final_message()

        add_assistant_message(messages, response)

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

        if tool_choice:
            break

    return messages

# %%
messages = []

add_user_message(
    messages,
    "Create and save a fake computer science article",
)

run_conversation(
    messages,
    tools=[save_article_schema],
)
# Out:
# I'll create a fake computer science article and save it right away!
#
#
# >>> Tool Call: "save_article"
# {"abstract": "This paper presents NeuroMesh, a novel distributed deep learning framework that leverages adaptive graph-based neural pruning to achieve state-of-the-art inference speeds across heterogeneous edge computing environments.", "meta": {"word_count":8432,"review":"This paper introduces NeuroMesh, a compelling distributed deep learning framework that addresses the growing challenge of deploying large-scale neural networks on resource-constrained edge devices. The authors propose an adaptive graph-based pruning mechanism that dynamically adjusts model sparsity based on real-time hardware telemetry, which is a genuinely innovative contribution to the field. The experimental results are thorough, spanning benchmarks across five different hardware architectures including ARM Cortex processors and RISC-V boards, lending credibility to the heterogeneous environment claims. The theoretical foundations are well-grounded, with the authors providing convergence proofs for their pruning algorithm under stochastic gradient descent conditions. One minor weakness is that the comparison baselines, while adequate, omit a few recent competitive methods published in late 2024 that would have strengthened the evaluation. The ablation studies in Section 5 are particularly well-constructed, isolating the contribution of each NeuroMesh component and clearly demonstrating the value of the graph-based coordination layer. Writing quality is high throughout, with clear figures and well-structured arguments that make the dense technical material accessible. Overall, this is a strong contribution to edge AI systems research and is recommended for acceptance with minor revisions addressing the missing baselines."}}
#
# The fake computer science article has been successfully created and saved! Here's a summary of what was generated:
#
# ---
#
# ### 📄 NeuroMesh: Adaptive Graph-Based Neural Pruning for Distributed Edge Inference
#
# - **Abstract:** A novel distributed deep learning framework called *NeuroMesh* that uses adaptive graph-based neural pruning to achieve fast inference on heterogeneous edge computing devices.
# - **Word Count:** 8,432 words
# - **Review Highlights:**
#   - ✅ Innovative adaptive pruning mechanism driven by real-time hardware telemetry
#   - ✅ Benchmarked across 5 hardware architectures (ARM Cortex, RISC-V, etc.)
#   - ✅ Includes convergence proofs and strong ablation studies
#   - ⚠️ Minor weakness: missing a few recent 2024 baseline comparisons
#   - 📝 **Verdict:** Recommended for acceptance with minor revisions
# [{'role': 'user',
#   'content': [{'type': 'text',
#     'text': 'Create and save a fake computer science article'}]},
#  {'role': 'assistant',
#   'content': [{'type': 'text',
#     'text': "I'll create a fake computer science article and save it right away!"},
#    {'type': 'tool_use',
#     'id': 'toolu_01FPoREyz2H8sT2YFyEPULAq',
#     'name': 'save_article',
#     'input': {'abstract': 'This paper presents NeuroMesh, a novel distributed deep learning framework that leverages adaptive graph-based neural pruning to achieve state-of-the-art inference speeds across heterogeneous edge computing environments.',
#      'meta': {'word_count': 8432,
#       'review': 'This paper introduces NeuroMesh, a compelling distributed deep learning framework that addresses the growing challenge of deploying large-scale neural networks on resource-constrained edge devices. The authors propose an adaptive graph-based pruning mechanism that dynamically adjusts model sparsity based on real-time hardware telemetry, which is a genuinely innovative contribution to the field. The experimental results are thorough, spanning benchmarks across five different hardware architectures including ARM Cortex processors and RISC-V boards, lending credibility to the heterogeneous environment claims. The theoretical foundations are well-grounded, with the authors providing convergence proofs for their pruning algorithm under stochastic gradient descent conditions. One minor weakness is that the comparison baselines, while adequate, omit a few recent competitive methods published in late 2024 that would have strengthened the evaluation. The ablation studies in Section 5 are particularly well-constructed, isolating the contribution of each NeuroMesh component and clearly demonstrating the value of the graph-based coordination layer. Writing quality is high throughout, with clear figures and well-structured arguments that make the dense technical material accessible. Overall, this is a strong contribution to edge AI systems research and is recommended for acceptance with minor revisions addressing the missing baselines.'}}}]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01FPoREyz2H8sT2YFyEPULAq',
#     'content': '"Article saved!"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [{'type': 'text',
#     'text': "The fake computer science article has been successfully created and saved! Here's a summary of what was generated:\n\n---\n\n### 📄 NeuroMesh: Adaptive Graph-Based Neural Pruning for Distributed Edge Inference\n\n- **Abstract:** A novel distributed deep learning framework called *NeuroMesh* that uses adaptive graph-based neural pruning to achieve fast inference on heterogeneous edge computing devices.\n- **Word Count:** 8,432 words\n- **Review Highlights:**\n  - ✅ Innovative adaptive pruning mechanism driven by real-time hardware telemetry\n  - ✅ Benchmarked across 5 hardware architectures (ARM Cortex, RISC-V, etc.)\n  - ✅ Includes convergence proofs and strong ablation studies\n  - ⚠️ Minor weakness: missing a few recent 2024 baseline comparisons\n  - 📝 **Verdict:** Recommended for acceptance with minor revisions"}]}]

# %%
messages = []

add_user_message(
    messages,
    "Create and save a fake computer science article",
)

run_conversation(
    messages,
    tools=[save_article_schema],
    fine_grained=True,
)
# Out:
# I'll create a fake computer science article and save it right away!
#
#
# >>> Tool Call: "save_article"
# {"abstract": "This paper presents NeuroMesh, a novel distributed deep learning framework that leverages adaptive graph-based neural architectures to achieve state-of-the-art performance in large-scale parallel model training across heterogeneous computing environments.", "meta": {"word_count": 8742, "review": "This paper introduces NeuroMesh, a compelling and timely contribution to the field of distributed machine learning systems. The authors present a well-structured argument for graph-based coordination of neural network training tasks across heterogeneous hardware clusters. The proposed adaptive mesh topology is particularly innovative, dynamically reconfiguring communication pathways to minimize bottlenecks during backpropagation. Experimental results across three benchmark datasets demonstrate a 37% reduction in training time compared to state-of-the-art baselines such as Horovod and PyTorch DDP. The theoretical analysis of convergence guarantees is rigorous and mathematically sound, lending strong credibility to the empirical findings. One minor weakness is the limited discussion of fault tolerance in scenarios involving frequent node dropout, which could be explored further. The writing is clear and well-organized, with thorough citations that appropriately contextualize the work within existing literature. Overall, NeuroMesh represents a significant step forward in scalable AI infrastructure and is highly recommended for acceptance."}}
#
# The fake computer science article has been successfully created and saved! Here's a summary of what was generated:
#
# ---
#
# 📄 **Title:** *NeuroMesh: Adaptive Graph-Based Neural Architectures for Distributed Deep Learning*
#
# **Abstract:**
# This paper presents NeuroMesh, a novel distributed deep learning framework that leverages adaptive graph-based neural architectures to achieve state-of-the-art performance in large-scale parallel model training across heterogeneous computing environments.
#
# **Word Count:** 8,742
#
# **Review Highlights:**
# - ✅ Introduces an innovative **adaptive mesh topology** that dynamically reconfigures communication pathways
# - 📊 Claims a **37% reduction in training time** vs. baselines like Horovod and PyTorch DDP
# - 🔢 Features **rigorous mathematical convergence guarantees**
# - ⚠️ Minor weakness noted: limited discussion of **fault tolerance** under node dropout
# - 🏆 Overall recommended for **acceptance**
#
# ---
#
# A convincing (but entirely fictional!) CS paper ready to go! 😄
# [{'role': 'user',
#   'content': [{'type': 'text',
#     'text': 'Create and save a fake computer science article'}]},
#  {'role': 'assistant',
#   'content': [{'type': 'text',
#     'text': "I'll create a fake computer science article and save it right away!"},
#    {'type': 'tool_use',
#     'id': 'toolu_01NwnAxVXFYkVpsyy7QZshFA',
#     'name': 'save_article',
#     'input': {'abstract': 'This paper presents NeuroMesh, a novel distributed deep learning framework that leverages adaptive graph-based neural architectures to achieve state-of-the-art performance in large-scale parallel model training across heterogeneous computing environments.',
#      'meta': {'word_count': 8742,
#       'review': 'This paper introduces NeuroMesh, a compelling and timely contribution to the field of distributed machine learning systems. The authors present a well-structured argument for graph-based coordination of neural network training tasks across heterogeneous hardware clusters. The proposed adaptive mesh topology is particularly innovative, dynamically reconfiguring communication pathways to minimize bottlenecks during backpropagation. Experimental results across three benchmark datasets demonstrate a 37% reduction in training time compared to state-of-the-art baselines such as Horovod and PyTorch DDP. The theoretical analysis of convergence guarantees is rigorous and mathematically sound, lending strong credibility to the empirical findings. One minor weakness is the limited discussion of fault tolerance in scenarios involving frequent node dropout, which could be explored further. The writing is clear and well-organized, with thorough citations that appropriately contextualize the work within existing literature. Overall, NeuroMesh represents a significant step forward in scalable AI infrastructure and is highly recommended for acceptance.'}}}]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01NwnAxVXFYkVpsyy7QZshFA',
#     'content': '"Article saved!"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [{'type': 'text',
#     'text': "The fake computer science article has been successfully created and saved! Here's a summary of what was generated:\n\n---\n\n📄 **Title:** *NeuroMesh: Adaptive Graph-Based Neural Architectures for Distributed Deep Learning*\n\n**Abstract:**\nThis paper presents NeuroMesh, a novel distributed deep learning framework that leverages adaptive graph-based neural architectures to achieve state-of-the-art performance in large-scale parallel model training across heterogeneous computing environments.\n\n**Word Count:** 8,742\n\n**Review Highlights:**\n- ✅ Introduces an innovative **adaptive mesh topology** that dynamically reconfigures communication pathways\n- 📊 Claims a **37% reduction in training time** vs. baselines like Horovod and PyTorch DDP\n- 🔢 Features **rigorous mathematical convergence guarantees**\n- ⚠️ Minor weakness noted: limited discussion of **fault tolerance** under node dropout\n- 🏆 Overall recommended for **acceptance**\n\n---\n\nA convincing (but entirely fictional!) CS paper ready to go! 😄"}]}]
